# %%
import pandas as pd

# %%
df = pd.read_pickle('data.pkl')

# %%
df.head(20)
# Out:
#      experiment_name dataset  dataset_min_range  dataset_max_range  \
# 0   SecondExperiment   cubic                 -1                  1
# 1   SecondExperiment   cubic                 -1                  1
# 2   SecondExperiment   cubic                 -1                  1
# 3   SecondExperiment   cubic                 -1                  1
# 4   SecondExperiment   cubic                 -1                  1
# 5   SecondExperiment   cubic                 -1                  1
# 6   SecondExperiment   cubic                 -1                  1
# 7   SecondExperiment   cubic                 -1                  1
# 8   SecondExperiment   cubic                 -1                  1
# 9   SecondExperiment   cubic                 -1                  1
# 10  SecondExperiment   cubic                 -1                  1
# 11  SecondExperiment   cubic                 -1                  1
# 12  SecondExperiment   cubic                 -1                  1
# ...
