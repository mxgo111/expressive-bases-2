# %%
import pandas as pd
from src.imports import *
from src.configurations import *

# %%
df = pd.read_pickle("experiments/TestExperiment/data.pkl")

# %%
df.head()
# Out:
#   experiment_name dataset  dataset_min_range  dataset_max_range  \
# 0  TestExperiment   cubic                 -1                  1
# 1  TestExperiment   cubic                 -1                  1
# 2  TestExperiment   cubic                 -1                  1
# 3  TestExperiment   cubic                 -1                  1
#
#    gap_min_range  gap_max_range  train_dataset_size  output_var  \
# 0           -0.2            0.2                 100        0.01
# 1           -0.2            0.2                 100        0.01
# 2           -0.2            0.2                 100        0.01
# 3           -0.2            0.2                 100        0.01
#
#             basis     final_layer  ... w_prior_var loss    k learning_rate  \
# 0  FullyConnected  FullyConnected  ...         1.0  MLE  0.1         0.001
# 1  FullyConnected  FullyConnected  ...         1.0  MLE  0.1         0.001
# 2  FullyConnected  FullyConnected  ...         1.0  MLE  0.1         0.001
# ...
